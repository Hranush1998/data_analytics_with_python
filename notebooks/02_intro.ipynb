# %% [markdown]
# Data Types

# %% [markdown]
# Integers

# %%
x = 42

# %%
x= 5
x = 4.1
x
# Out:
# 4.1

# %%
a = 5
b = 2

div1 = a / b
div2 = a // b

# %%
(f"simple division: {div1}")
(f"integer division: {div2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 (f"simple division: {div1}")
#       2 (f"integer division: {div2}")
#
# NameError: name 'div1' is not defined
