# %% [markdown]
# ## Arithmetic Operators

# %%
r = 1500
t = 0.2

total = r * (1 + t)
total
# Out:
# 1800.0

# %%
2!=3
# Out:
# True

# %% [markdown]
# ### List

# %%
l = [10,20,30,40]

# %%
l[-1]
# Out:
# 40
