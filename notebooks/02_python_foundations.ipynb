# %% [markdown]
# Session 01: Programming for Data Analysts
# Why Programming for Data Analysts?

# %% [markdown]
# Data Types

# %% [markdown]
# Integers

# %%
x = 42
x
# Out:
# 42

# %%
y = '34'
y
# Out:
# '34'

# %%
x == y
# Out:
# False

# %%
type(x)
# Out:
# int

# %% [markdown]
# Float

# %%
x= 5
x = 4.1
x
# Out:
# 4.1

# %%
type(x)
# Out:
# float

# %%
a = 5
b = 4.1
c = 2.9

a + b + c
# Out:
# 12.0

# %%
d = a + b + c

# %%
float(int(d))
# Out:
# 12.0

# %%
type(d)
# Out:
# float

# %%
a = 5
b = 2 

div1 = a/b
div2 = a//b

# %%
print(f"simple division: {div1}")
print(f"integer divisoin: {div2}")
# Out:
# simple division: 2.5
# integer divisoin: 2

# %% [markdown]
# String

# %%
first_name = "Hranush"
last_name = "Navoyan"

# %%
first_name
last_name
# Out:
# 'Navoyan'

# %%
type(first_name)
# Out:
# str

# %%
a = '11'

# %%
a + "2"
# Out:
# '112'

# %%
full_name = first_name + " " + last_name

# %%
full_name
# Out:
# 'Hranush Navoyan'

# %% [markdown]
# -- возводит в степень и распределяет умножение от 0 до 4

# %%
N = 5
power = 4
for i in range(N):
    print(f"{i} power of {power} {i**power}")
# Out:
# 0 power of 4 0
# 1 power of 4 1
# 2 power of 4 16
# 3 power of 4 81
# 4 power of 4 256

# %% [markdown]
# Boolean Values

# %%
is_active = True
is_active2 = False

# %%
type(is_active)
# Out:
# bool

# %%
x = 42

# %%
x > 40
# Out:
# True

# %%
x = 42

# %%
x == 42
# Out:
# True

# %%
x<=42
# Out:
# True

# %%
x = "42"

# %%
x
# Out:
# '42'

# %%
x = 42
y = 32
z = x + y

type ( x +y )
# Out:
# int

# %%
type(z)
# Out:
# int

# %%
var_name = "value"
