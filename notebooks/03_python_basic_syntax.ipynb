# %%
a = 5

# %%
b = a*4

# %%
b
# Out:
# 20

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Общий доход, включая налоги, составляет

# %%
r = 100
t = 0.2

total = r * (1 + t)
total
# Out:
# 120.0

# %%
100 > 50
# Out:
# True

# %%
100 == 50
# Out:
# False

# %%
100 != 50
# Out:
# True

# %%
print((100 > 50) and (20 < 30))
# Out:
# True

# %% [markdown]
# List

# %%
sales = [100,200,150,200]
sales
# Out:
# [100, 200, 150, 200]

# %%
sales[0]
# Out:
# 100

# %%
sales[-1]
# Out:
# 200

# %%
sales.append(300)
sales[1] = 250
sales
# Out:
# [100, 250, 150, 200, 300]

# %%
sales.remove(150)
sales
# Out:
# [100, 250, 200, 300]

# %%
len(sales)
# Out:
# 4

# %%
total = 0
for value in sales:
    total += value

# %%
total
# Out:
# 850

# %% [markdown]
# Tuple

# %%
coordinates = (40.18, 44.51)
coordinates
# Out:
# (40.18, 44.51)

# %% [markdown]
# Set

# %%
customer_ids = {1, 2, 3, 3, 4}
customer_ids
# Out:
# {1, 2, 3, 4}

# %%
segment_a = {1, 2, 3}
segment_b = {3, 4, 5}

segment_a.intersection(segment_b)
# Out:
# {3}

# %% [markdown]
# Dictionary
